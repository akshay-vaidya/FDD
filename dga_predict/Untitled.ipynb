# %%
import os

# %%
os.getcwd()
# Out:
# '/home/akshayaa/Documents/dga_edited'

# %%
pickle.load(open('traindata.pkl'))
# Out:
# [('spam', 'pdtmstring'),
#  ('spam', 'umfpstring'),
#  ('spam', 'cmzmstring'),
#  ('spam', 'hrynstring'),
#  ('spam', 'nhdjstring'),
#  ('spam', 'ppkustring'),
#  ('spam', 'csecstring'),
#  ('spam', 'xttastring'),
#  ('spam', 'qobbstring'),
#  ('spam', 'kydostring'),
#  ('spam', 'rzmlstring'),
#  ('spam', 'vfzbstring'),
#  ('spam', 'plgestring'),
#  ('spam', 'mukustring'),
#  ('spam', 'zzbgstring'),
#  ('spam', 'yirrstring'),
#  ('spam', 'ikrestring'),
#  ('spam', 'flopstring'),
#  ('spam', 'nvtpstring'),
#  ('spam', 'vxgestring'),
#  ('spam', 'syqestring'),
#  ('spam', 'pxxkstring'),
#  ('spam', 'syhbstring'),
#  ('spam', 'mulsstring'),
#  ('spam', 'xxabstring'),
#  ('spam', 'rxjtstring'),
#  ('spam', 'djesstring'),
#  ('spam', 'oskgstring'),
#  ('spam', 'njpqstring'),
#  ('spam', 'wadfstring'),
#  ('spam', 'ugpmstring'),
#  ('spam', 'zxgbstring'),
#  ('spam', 'tzrdstring'),
#  ('spam', 'pzymstring'),
#  ('spam', 'uekmstring'),
#  ('spam', 'ztbsstring'),
#  ('spam', 'kidpstring'),
# ...

# %%
import cPickle as pickle
